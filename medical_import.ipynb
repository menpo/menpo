# %% [markdown]
# **Great Ormand Street data importer**

# %%
import os
from ibugMM.importer.model import import_face
from ibugMM.importer.model import process_with_meshlabserver
from ibugMM.importer.metadata import medical_landmarks
import re
from ibugMM.alignment.rigid import Procrustes

# %%
medical_dir = '/home/jab08/Dropbox/testData/medicaldata/'
all_files = os.listdir(medical_dir)
med_stls = [f for f in all_files if f.lower().endswith('.stl')]
med_lms = [f for f in all_files if f.lower().endswith('.lan')]
print 'found ' + `len(med_stls)` + ' medical .stl files'
print 'found ' + `len(med_lms)` + ' medical .lan files'

# %% [markdown]
# *Find the unique identifiers on the lm's and on the stl files*

# %%
lm_names = [f.split('.')[0].lower() for f in med_lms]
lm_names_tuple = [(f.split('.')[0].lower(), f) for f in med_lms]
unique_lm_names = set(lm_names)
print `len(lm_names)` + ' lm names found'
print `len(unique_lm_names)` + ' of which are unique'

# npow for the stl landmarks...
# find any letters optionally followed by letters before the 
# file extension
prog = re.compile(r'([a-z]+\d*)[.]', re.IGNORECASE)
stl_names = [prog.findall(f)[0].lower() for f in med_stls]
stl_names_tuple = [(prog.findall(f)[0].lower(), f) for f in med_stls]
unique_stl_names = set(stl_names)
print `len(stl_names)` + ' stl names found'
print `len(unique_stl_names)` + ' of which are unique'
# Out:
# 96 lm names found
# 90 of which are unique

# %% [markdown]
# *Find what lm and stl names are fully shared and build a list of tuples, each element* `(stl_filename, matching_lm_filename)`

# %%
faces_with_lms = unique_stl_names.intersection(unique_lm_names)
stl_lookup = dict(stl_names_tuple)
lm_lookup = dict(lm_names_tuple)
paired_stl_lm = []
for id_ in faces_with_lms:
    paired_stl_lm.append((stl_lookup[id_], lm_lookup[id_]))

# now we loop through building faces and attatching the landmarks on them
faces = []
lms = []
for i in paired_stl_lm:
    lm_path = os.path.join(medical_dir, i[1])
    obj_filename = os.path.splitext(i[0])[0] + '.obj'
    obj_path = os.path.join(medical_dir, obj_filename)
    lms.append(medical_landmarks(lm_path))
    #face = import_face(obj_path)
    #face.lm = medical_landmarks(lm_path)
    #faces.append(face)

# %% [markdown]
# *Align the faces landmarks using Generalised Procrustes Analysis*

# %%
proc = Procrustes(lms)
proc.general_alignment()
# Out:
# taking Procrustes step
# error is 36.762659435124021
# taking Procrustes step
# error is 25.626335389359031
# taking Procrustes step
# error is 20.755651642246615
# taking Procrustes step
# error is 19.065366992644847
# taking Procrustes step
# error is 18.326670775631943
# taking Procrustes step
# error is 17.897020800510099
# taking Procrustes step
# error is 17.572870659987984
# taking Procrustes step
# error is 17.28705700963372
# taking Procrustes step
# error is 17.016981915630652
# taking Procrustes step
# error is 16.75493587413434
# taking Procrustes step
# error is 16.498242092146331
# taking Procrustes step
# error is 16.245939270022021
# taking Procrustes step
# error is 15.99765538980639
# taking Procrustes step
# error is 15.753222612775456
# taking Procrustes step
# error is 15.512544698660719
# taking Procrustes step
# error is 15.275551049344257
# taking Procrustes step
# error is 15.042180666063729
# taking Procrustes step
# error is 14.812376505702122
# taking Procrustes step
# error is 14.586083476691575
# taking Procrustes step
# error is 14.363247717370911
# taking Procrustes step
# error is 14.143816329364441
# taking Procrustes step
# error is 13.927737273530818
# taking Procrustes step
# error is 13.71495932443529
# taking Procrustes step
# error is 13.505432046100152
# taking Procrustes step
# error is 13.299105775611634
# taking Procrustes step
# error is 13.095931609714704
# taking Procrustes step
# error is 12.895861392612462
# taking Procrustes step
# error is 12.69884770432922
# taking Procrustes step
# error is 12.504843849387992
# taking Procrustes step
# error is 12.313803845710519
# taking Procrustes step
# error is 12.125682413707848
# taking Procrustes step
# error is 11.94043496553901
# taking Procrustes step
# error is 11.75801759454707
# taking Procrustes step
# error is 11.578387064849201
# taking Procrustes step
# error is 11.40150080109313
# taking Procrustes step
# error is 11.227316878354538
# taking Procrustes step
# error is 11.055794012215095
# taking Procrustes step
# error is 10.886891548967114
# taking Procrustes step
# error is 10.720569455981526
# taking Procrustes step
# error is 10.556788312217591
# taking Procrustes step
# error is 10.39550929888277
# taking Procrustes step
# error is 10.236694190228981
# taking Procrustes step
# error is 10.080305344494953
# taking Procrustes step
# error is 9.9263056949810853
# taking Procrustes step
# error is 9.7746587412678529
# taking Procrustes step
# error is 9.6253285405604974
# taking Procrustes step
# error is 9.4782796991787439
# taking Procrustes step
# error is 9.3334773641507596
# taking Procrustes step
# error is 9.1908872149722871
# taking Procrustes step
# error is 9.0504754554627649
# taking Procrustes step
# error is 8.912208805748584
# taking Procrustes step
# error is 8.7760544943878696
# taking Procrustes step
# error is 8.6419802505971042
# taking Procrustes step
# error is 8.509954296599064
# taking Procrustes step
# error is 8.3799453400974429
# taking Procrustes step
# error is 8.2519225668563614
# taking Procrustes step
# error is 8.1258556333979541
# taking Procrustes step
# error is 8.0017146598082505
# taking Procrustes step
# error is 7.8794702226600153
# taking Procrustes step
# error is 7.7590933480347193
# taking Procrustes step
# error is 7.6405555046550289
# taking Procrustes step
# error is 7.5238285971256476
# taking Procrustes step
# error is 7.4088849592736681
# taking Procrustes step
# error is 7.2956973475872156
# taking Procrustes step
# error is 7.1842389347615825
# taking Procrustes step
# error is 7.0744833033428858
# taking Procrustes step
# error is 6.9664044394619156
# taking Procrustes step
# error is 6.8599767266712401
# taking Procrustes step
# error is 6.7551749398727354
# taking Procrustes step
# error is 6.6519742393386405
# taking Procrustes step
# error is 6.5503501648274387
# taking Procrustes step
# error is 6.4502786297787136
# taking Procrustes step
# error is 6.3517359156143254
# taking Procrustes step
# error is 6.2546986661088217
# taking Procrustes step
# error is 6.1591438818559192
# taking Procrustes step
# error is 6.0650489148187736
# taking Procrustes step
# error is 5.9723914629615109
# taking Procrustes step
# error is 5.8811495649612269
# taking Procrustes step
# error is 5.7913015950050299
# taking Procrustes step
# error is 5.7028262576630384
# taking Procrustes step
# error is 5.6157025828435758
# taking Procrustes step
# error is 5.5299099208183042
# taking Procrustes step
# error is 5.4454279373319823
# taking Procrustes step
# error is 5.3622366087816804
# taking Procrustes step
# error is 5.2803162174694647
# taking Procrustes step
# error is 5.1996473469322995
# taking Procrustes step
# error is 5.1202108773360999
# taking Procrustes step
# error is 5.0419879809458017
# taking Procrustes step
# error is 4.9649601176633285
# taking Procrustes step
# error is 4.8891090306336302
# taking Procrustes step
# error is 4.8144167419157089
# taking Procrustes step
# error is 4.7408655482236828
# taking Procrustes step
# error is 4.6684380167290156
# taking Procrustes step
# error is 4.5971169809286474
# taking Procrustes step
# error is 4.5268855365777521
# taking Procrustes step
# error is 4.4577270376834894
# taking Procrustes step
# error is 4.3896250925570461
# taking Procrustes step
# error is 4.3225635599297076
# taking Procrustes step
# error is 4.2565265451293923
# taking Procrustes step
# error is 4.1914983963091883
# taking Procrustes step
# error is 4.1274637007407788
# taking Procrustes step
# error is 4.0644072811606797
# taking Procrustes step
# error is 4.0023141921727632
# taking Procrustes step
# error is 3.9411697167058537
# taking Procrustes step
# error is 3.8809593625240466
# taking Procrustes step
# error is 3.8216688587963201
# taking Procrustes step
# error is 3.763284152708585
# taking Procrustes step
# error is 3.7057914061368806
# taking Procrustes step
# error is 3.6491769923656872
# taking Procrustes step
# error is 3.5934274928579533
# taking Procrustes step
# error is 3.5385296940768152
# taking Procrustes step
# error is 3.4844705843514641
# taking Procrustes step
# error is 3.4312373507947109
# taking Procrustes step
# error is 3.3788173762636249
# taking Procrustes step
# error is 3.3271982363733041
# taking Procrustes step
# error is 3.2763676965475677
# taking Procrustes step
# error is 3.2263137091232315
# taking Procrustes step
# error is 3.1770244104914602
# taking Procrustes step
# error is 3.1284881182869397
# taking Procrustes step
# error is 3.0806933286196019
# taking Procrustes step
# error is 3.03362871334688
# taking Procrustes step
# error is 2.987283117390676
# taking Procrustes step
# error is 2.941645556091391
# taking Procrustes step
# error is 2.8967052126047443
# taking Procrustes step
# error is 2.8524514353389607
# taking Procrustes step
# error is 2.8088737354296769
# taking Procrustes step
# error is 2.7659617842532418
# taking Procrustes step
# error is 2.7237054109801289
# taking Procrustes step
# error is 2.6820946001630372
# taking Procrustes step
# error is 2.6411194893629588
# taking Procrustes step
# error is 2.6007703668131508
# taking Procrustes step
# error is 2.5610376691150005
# taking Procrustes step
# error is 2.5219119789742881
# taking Procrustes step
# error is 2.4833840229657054
# taking Procrustes step
# error is 2.445444669337145
# taking Procrustes step
# error is 2.4080849258461079
# taking Procrustes step
# error is 2.3712959376251157
# taking Procrustes step
# error is 2.3350689850870916
# taking Procrustes step
# error is 2.2993954818541709
# taking Procrustes step
# error is 2.2642669727268698
# taking Procrustes step
# error is 2.2296751316775669
# taking Procrustes step
# error is 2.1956117598774321
# taking Procrustes step
# error is 2.1620687837539991
# taking Procrustes step
# error is 2.1290382530759562
# taking Procrustes step
# error is 2.0965123390713276
# taking Procrustes step
# error is 2.0644833325696763
# taking Procrustes step
# error is 2.0329436421756149
# taking Procrustes step
# error is 2.0018857924700186
# taking Procrustes step
# error is 1.9713024222376074
# taking Procrustes step
# error is 1.9411862827222011
# taking Procrustes step
# error is 1.9115302359099391
# taking Procrustes step
# error is 1.8823272528348467
# taking Procrustes step
# error is 1.8535704119159488
# taking Procrustes step
# error is 1.8252528973141839
# taking Procrustes step
# error is 1.797367997317963
# taking Procrustes step
# error is 1.7699091027532841
# taking Procrustes step
# error is 1.7428697054156812
# taking Procrustes step
# error is 1.7162433965282673
# taking Procrustes step
# error is 1.6900238652229502
# taking Procrustes step
# error is 1.664204897044947
# taking Procrustes step
# error is 1.6387803724789072
# taking Procrustes step
# error is 1.613744265499423
# taking Procrustes step
# error is 1.589090642141707
# taking Procrustes step
# error is 1.5648136590968926
# taking Procrustes step
# error is 1.5409075623251154
# taking Procrustes step
# error is 1.5173666856925918
# taking Procrustes step
# error is 1.4941854496296054
# taking Procrustes step
# error is 1.4713583598054125
# taking Procrustes step
# error is 1.4488800058294651
# taking Procrustes step
# error is 1.426745059966223
# taking Procrustes step
# error is 1.4049482758738776
# taking Procrustes step
# error is 1.3834844873599146
# taking Procrustes step
# error is 1.3623486071579647
# taking Procrustes step
# error is 1.3415356257206141
# taking Procrustes step
# error is 1.3210406100328835
# taking Procrustes step
# error is 1.3008587024431284
# taking Procrustes step
# error is 1.2809851195111002
# taking Procrustes step
# error is 1.2614151508748979
# taking Procrustes step
# error is 1.2421441581333672
# taking Procrustes step
# error is 1.2231675737481309
# taking Procrustes step
# error is 1.2044808999603818
# taking Procrustes step
# error is 1.1860797077244973
# taking Procrustes step
# error is 1.1679596356588537
# taking Procrustes step
# error is 1.1501163890120578
# taking Procrustes step
# error is 1.1325457386443334
# taking Procrustes step
# error is 1.1152435200260338
# taking Procrustes step
# error is 1.0982056322501643
# taking Procrustes step
# error is 1.0814280370602418
# taking Procrustes step
# error is 1.0649067578934581
# taking Procrustes step
# error is 1.0486378789383781
# taking Procrustes step
# error is 1.0326175442059551
# taking Procrustes step
# error is 1.016841956616559
# taking Procrustes step
# error is 1.0013073770995577
# taking Procrustes step
# error is 0.98601012370711127
# taking Procrustes step
# error is 0.97094657074132318
# taking Procrustes step
# error is 0.95611314789537749
# taking Procrustes step
# error is 0.94150633940696604
# taking Procrustes step
# error is 0.9271226832251368
# taking Procrustes step
# error is 0.91295877018942662
# taking Procrustes step
# error is 0.89901124322215542
# taking Procrustes step
# error is 0.8852767965329168
# taking Procrustes step
# error is 0.87175217483457512
# taking Procrustes step
# error is 0.85843417257176857
# taking Procrustes step
# error is 0.84531963316167791
# taking Procrustes step
# error is 0.83240544824501372
# taking Procrustes step
# error is 0.81968855695037401
# taking Procrustes step
# error is 0.80716594516758045
# taking Procrustes step
# error is 0.79483464483424138
# taking Procrustes step
# error is 0.7826917332316089
# taking Procrustes step
# error is 0.77073433229227561
# taking Procrustes step
# error is 0.75895960791780948
# taking Procrustes step
# error is 0.74736476930729967
# taking Procrustes step
# error is 0.73594706829536438
# taking Procrustes step
# error is 0.72470379870139523
# taking Procrustes step
# error is 0.71363229568757669
# taking Procrustes step
# error is 0.70272993512786019
# taking Procrustes step
# error is 0.69199413298550061
# taking Procrustes step
# error is 0.68142234470093832
# taking Procrustes step
# error is 0.67101206458858309
# taking Procrustes step
# error is 0.66076082524274837
# taking Procrustes step
# error is 0.65066619695299555
# taking Procrustes step
# error is 0.6407257871283768
# taking Procrustes step
# error is 0.6309372397302655
# taking Procrustes step
# error is 0.62129823471367562
# taking Procrustes step
# error is 0.61180648747789501
# taking Procrustes step
# error is 0.60245974832449989
# taking Procrustes step
# error is 0.59325580192427552
# taking Procrustes step
# error is 0.58419246679249281
# taking Procrustes step
# error is 0.57526759477123257
# taking Procrustes step
# error is 0.56647907052085167
# taking Procrustes step
# error is 0.5578248110181856
# taking Procrustes step
# error is 0.54930276506311204
# taking Procrustes step
# error is 0.54091091279223091
# taking Procrustes step
# error is 0.53264726520006878
# taking Procrustes step
# error is 0.52450986366789998
# taking Procrustes step
# error is 0.51649677949917827
# taking Procrustes step
# error is 0.50860611346281759
# taking Procrustes step
# error is 0.50083599534273049
# taking Procrustes step
# error is 0.49318458349443678
# taking Procrustes step
# error is 0.48565006440915498
# taking Procrustes step
# error is 0.4782306522833033
# taking Procrustes step
# error is 0.47092458859558733
# taking Procrustes step
# error is 0.46373014169019011
# taking Procrustes step
# error is 0.45664560636624457
# taking Procrustes step
# error is 0.44966930347367812
# taking Procrustes step
# error is 0.44279957951542881
# taking Procrustes step
# error is 0.43603480625506746
# taking Procrustes step
# error is 0.42937338033155753
# taking Procrustes step
# error is 0.42281372287855462
# taking Procrustes step
# error is 0.41635427915062767
# taking Procrustes step
# error is 0.40999351815467189
# taking Procrustes step
# error is 0.40372993228688581
# taking Procrustes step
# error is 0.39756203697558229
# taking Procrustes step
# error is 0.39148837032940675
# taking Procrustes step
# error is 0.38550749279056262
# taking Procrustes step
# error is 0.37961798679389752
# taking Procrustes step
# error is 0.37381845643074574
# taking Procrustes step
# error is 0.36810752711807454
# taking Procrustes step
# error is 0.36248384527294197
# taking Procrustes step
# error is 0.35694607799122685
# taking Procrustes step
# error is 0.35149291273208988
# taking Procrustes step
# error is 0.34612305700674001
# taking Procrustes step
# error is 0.34083523807210386
# taking Procrustes step
# error is 0.33562820262912535
# taking Procrustes step
# error is 0.33050071652570101
# taking Procrustes step
# error is 0.32545156446436557
# taking Procrustes step
# error is 0.32047954971395642
# taking Procrustes step
# error is 0.31558349382624346
# taking Procrustes step
# error is 0.31076223635625971
# taking Procrustes step
# error is 0.30601463458769002
# taking Procrustes step
# error is 0.30133956326180544
# taking Procrustes step
# error is 0.29673591431057728
# taking Procrustes step
# error is 0.29220259659452524
# taking Procrustes step
# error is 0.28773853564346097
# taking Procrustes step
# error is 0.28334267340257802
# taking Procrustes step
# error is 0.27901396798097122
# taking Procrustes step
# error is 0.27475139340508459
# taking Procrustes step
# error is 0.27055393937546468
# taking Procrustes step
# error is 0.2664206110273204
# taking Procrustes step
# error is 0.26235042869464259
# taking Procrustes step
# error is 0.25834242767797022
# taking Procrustes step
# error is 0.25439565801601732
# taking Procrustes step
# error is 0.25050918426015545
# taking Procrustes step
# error is 0.24668208525299593
# taking Procrustes step
# error is 0.24291345390978364
# taking Procrustes step
# error is 0.23920239700367374
# taking Procrustes step
# error is 0.23554803495385584
# taking Procrustes step
# error is 0.23194950161713088
# taking Procrustes step
# error is 0.22840594408260956
# taking Procrustes step
# error is 0.22491652246949723
# taking Procrustes step
# error is 0.22148040972823979
# taking Procrustes step
# error is 0.21809679144418834
# taking Procrustes step
# error is 0.21476486564484462
# taking Procrustes step
# error is 0.21148384260965955
# taking Procrustes step
# error is 0.20825294468278654
# taking Procrustes step
# error is 0.20507140608893165
# taking Procrustes step
# error is 0.20193847275171234
# taking Procrustes step
# error is 0.19885340211505176
# taking Procrustes step
# error is 0.19581546296697189
# taking Procrustes step
# error is 0.19282393526660924
# taking Procrustes step
# error is 0.18987810997320009
# taking Procrustes step
# error is 0.18697728887832785
# taking Procrustes step
# error is 0.18412078444019511
# taking Procrustes step
# error is 0.18130791962081641
# taking Procrustes step
# error is 0.17853802772554739
# taking Procrustes step
# error is 0.17581045224493838
# taking Procrustes step
# error is 0.17312454669929128
# taking Procrustes step
# error is 0.17047967448532139
# taking Procrustes step
# error is 0.16787520872534026
# taking Procrustes step
# error is 0.16531053211860741
# taking Procrustes step
# error is 0.1627850367950846
# taking Procrustes step
# error is 0.16029812417132652
# taking Procrustes step
# error is 0.15784920480862114
# taking Procrustes step
# error is 0.1554376982732866
# taking Procrustes step
# error is 0.15306303299901719
# taking Procrustes step
# error is 0.15072464615161965
# taking Procrustes step
# error is 0.14842198349537133
# taking Procrustes step
# error is 0.14615449926177621
# taking Procrustes step
# error is 0.14392165602022738
# taking Procrustes step
# error is 0.14172292455057484
# taking Procrustes step
# error is 0.13955778371774935
# taking Procrustes step
# error is 0.13742572034813952
# taking Procrustes step
# error is 0.13532622910808284
# taking Procrustes step
# error is 0.13325881238405415
# taking Procrustes step
# error is 0.13122298016463452
# taking Procrustes step
# error is 0.12921824992454545
# taking Procrustes step
# error is 0.12724414651009186
# taking Procrustes step
# error is 0.12530020202671224
# taking Procrustes step
# error is 0.12338595572795735
# taking Procrustes step
# error is 0.12150095390632425
# taking Procrustes step
# error is 0.1196447497857402
# taking Procrustes step
# error is 0.11781690341565959
# taking Procrustes step
# error is 0.11601698156678646
# taking Procrustes step
# error is 0.1142445576283951
# taking Procrustes step
# error is 0.11249921150719169
# taking Procrustes step
# error is 0.11078052952776274
# taking Procrustes step
# error is 0.10908810433455506
# taking Procrustes step
# error is 0.10742153479529122
# taking Procrustes step
# error is 0.10578042590588423
# taking Procrustes step
# error is 0.10416438869686441
# taking Procrustes step
# error is 0.10257304014114987
# taking Procrustes step
# error is 0.1010060030632615
# taking Procrustes step
# error is 0.099462906049938446
# taking Procrustes step
# error is 0.097943383362091949
# taking Procrustes step
# error is 0.096447074848171055
# taking Procrustes step
# error is 0.094973625858711927
# taking Procrustes step
# error is 0.093522687162368862
# taking Procrustes step
# error is 0.092093914863081078
# taking Procrustes step
# error is 0.090686970318587939
# taking Procrustes step
# error is 0.089301520060157347
# taking Procrustes step
# error is 0.087937235713570122
# taking Procrustes step
# error is 0.086593793921251536
# taking Procrustes step
# error is 0.08527087626565856
# taking Procrustes step
# error is 0.083968169193821093
# taking Procrustes step
# error is 0.082685363942965204
# taking Procrustes step
# error is 0.081422156467395104
# taking Procrustes step
# error is 0.080178247366424996
# taking Procrustes step
# error is 0.078953341813359779
# taking Procrustes step
# error is 0.077747149485674058
# taking Procrustes step
# error is 0.076559384496190361
# taking Procrustes step
# error is 0.075389765325294886
# taking Procrustes step
# error is 0.074238014754237636
# taking Procrustes step
# error is 0.07310385979939299
# taking Procrustes step
# error is 0.071987031647616037
# taking Procrustes step
# error is 0.070887265592486967
# taking Procrustes step
# error is 0.069804300971558653
# taking Procrustes step
# error is 0.068737881104618898
# taking Procrustes step
# error is 0.06768775323282708
# taking Procrustes step
# error is 0.066653668458799914
# taking Procrustes step
# error is 0.065635381687648667
# taking Procrustes step
# error is 0.064632651568853394
# taking Procrustes step
# error is 0.063645240439071563
# taking Procrustes step
# error is 0.062672914265823346
# taking Procrustes step
# error is 0.061715442591983957
# taking Procrustes step
# error is 0.060772598481215037
# taking Procrustes step
# error is 0.059844158464140394
# taking Procrustes step
# error is 0.058929902485385141
# taking Procrustes step
# error is 0.058029613851409541
# taking Procrustes step
# error is 0.057143079179186429
# taking Procrustes step
# error is 0.056270088345575613
# taking Procrustes step
# error is 0.055410434437567664
# taking Procrustes step
# error is 0.054563913703205409
# taking Procrustes step
# error is 0.053730325503319867
# taking Procrustes step
# error is 0.052909472263956044
# taking Procrustes step
# error is 0.052101159429561776
# taking Procrustes step
# error is 0.051305195416843016
# taking Procrustes step
# error is 0.050521391569396348
# taking Procrustes step
# error is 0.049749562112972948
# taking Procrustes step
# error is 0.048989524111442466
# taking Procrustes step
# error is 0.048241097423446115
# taking Procrustes step
# error is 0.047504104659683195
# taking Procrustes step
# error is 0.0467783711409012
# taking Procrustes step
# error is 0.046063724856455046
# taking Procrustes step
# error is 0.045359996423559673
# taking Procrustes step
# error is 0.044667019047135187
# taking Procrustes step
# error is 0.043984628480283276
# taking Procrustes step
# error is 0.043312662985340311
# taking Procrustes step
# error is 0.042650963295570242
# taking Procrustes step
# error is 0.041999372577384807
# taking Procrustes step
# error is 0.041357736393193116
# taking Procrustes step
# error is 0.040725902664791799
# taking Procrustes step
# error is 0.040103721637320233
# taking Procrustes step
# error is 0.039491045843749337
# taking Procrustes step
# error is 0.038887730069966278
# taking Procrustes step
# error is 0.038293631320326746
# taking Procrustes step
# error is 0.037708608783765467
# taking Procrustes step
# error is 0.037132523800436669
# taking Procrustes step
# error is 0.036565239828829955
# taking Procrustes step
# error is 0.03600662241342225
# taking Procrustes step
# error is 0.035456539152814714
# taking Procrustes step
# error is 0.034914859668321939
# taking Procrustes step
# error is 0.034381455573114221
# taking Procrustes step
# error is 0.033856200441734
# taking Procrustes step
# error is 0.033338969780192657
# taking Procrustes step
# error is 0.0328296409964077
# taking Procrustes step
# error is 0.032328093371175731
# taking Procrustes step
# error is 0.031834208029565145
# taking Procrustes step
# error is 0.031347867912721851
# taking Procrustes step
# error is 0.030868957750120083
# taking Procrustes step
# error is 0.030397364032280747
# taking Procrustes step
# error is 0.029932974983820918
# taking Procrustes step
# error is 0.029475680536987594
# taking Procrustes step
# error is 0.029025372305564789
# taking Procrustes step
# error is 0.02858194355918205
# taking Procrustes step
# error is 0.028145289198017689
# taking Procrustes step
# error is 0.027715305727889463
# taking Procrustes step
# error is 0.027291891235731679
# taking Procrustes step
# error is 0.026874945365418082
# taking Procrustes step
# error is 0.026464369294006255
# taking Procrustes step
# error is 0.026060065708291266
# taking Procrustes step
# error is 0.025661938781752609
# taking Procrustes step
# error is 0.025269894151834872
# taking Procrustes step
# error is 0.024883838897588915
# taking Procrustes step
# error is 0.024503681517648805
# taking Procrustes step
# error is 0.024129331908526681
# taking Procrustes step
# error is 0.023760701343291109
# taking Procrustes step
# error is 0.023397702450495869
# taking Procrustes step
# error is 0.023040249193508798
# taking Procrustes step
# error is 0.022688256850097684
# taking Procrustes step
# error is 0.022341641992354461
# taking Procrustes step
# error is 0.022000322466923145
# taking Procrustes step
# error is 0.021664217375528524
# taking Procrustes step
# error is 0.021333247055799944
# taking Procrustes step
# error is 0.02100733306239453
# taking Procrustes step
# error is 0.020686398148394253
# taking Procrustes step
# error is 0.020370366247008467
# taking Procrustes step
# error is 0.020059162453544284
# taking Procrustes step
# error is 0.019752713007639335
# taking Procrustes step
# error is 0.01945094527579198
# taking Procrustes step
# error is 0.019153787734147092
# taking Procrustes step
# error is 0.018861169951539827
# taking Procrustes step
# error is 0.018573022572793585
# taking Procrustes step
# error is 0.018289277302301281
# taking Procrustes step
# error is 0.018009866887817822
# taking Procrustes step
# error is 0.017734725104537604
# taking Procrustes step
# error is 0.017463786739380389
# taking Procrustes step
# error is 0.017196987575550632
# taking Procrustes step
# error is 0.016934264377310836
# taking Procrustes step
# error is 0.016675554874995675
# taking Procrustes step
# error is 0.016420797750241866
# taking Procrustes step
# error is 0.016169932621473714
# taking Procrustes step
# error is 0.015922900029576532
# taking Procrustes step
# error is 0.015679641423809274
# taking Procrustes step
# error is 0.015440099147930771
# taking Procrustes step
# error is 0.015204216426528248
# taking Procrustes step
# error is 0.01497193735155969
# taking Procrustes step
# error is 0.01474320686911014
# taking Procrustes step
# error is 0.014517970766337264
# taking Procrustes step
# error is 0.01429617565862356
# taking Procrustes step
# error is 0.014077768976923215
# taking Procrustes step
# error is 0.013862698955303496
# taking Procrustes step
# error is 0.013650914618670773
# taking Procrustes step
# error is 0.013442365770697323
# taking Procrustes step
# error is 0.013237002981914131
# taking Procrustes step
# error is 0.013034777578004251
# taking Procrustes step
# error is 0.012835641628257828
# taking Procrustes step
# error is 0.012639547934221109
# taking Procrustes step
# error is 0.01244645001849728
# taking Procrustes step
# error is 0.012256302113741371
# taking Procrustes step
# error is 0.012069059151811919
# taking Procrustes step
# error is 0.01188467675308395
# taking Procrustes step
# error is 0.01170311121592906
# taking Procrustes step
# error is 0.011524319506364305
# taking Procrustes step
# error is 0.011348259247848292
# taking Procrustes step
# error is 0.011174888711239429
# taking Procrustes step
# error is 0.011004166804901759
# taking Procrustes step
# error is 0.0108360530649666
# taking Procrustes step
# error is 0.010670507645747448
# taking Procrustes step
# error is 0.010507491310287234
# taking Procrustes step
# error is 0.010346965421064353
# taking Procrustes step
# error is 0.01018889193083544
# taking Procrustes step
# error is 0.010033233373613759
# taking Procrustes step
# error is 0.0098799528557897212
# taking Procrustes step
# error is 0.0097290140473898692
# taking Procrustes step
# error is 0.0095803811734628871
# taking Procrustes step
# error is 0.0094340190056004716
# taking Procrustes step
# error is 0.0092898928535930254
# taking Procrustes step
# error is 0.0091479685571972738
# taking Procrustes step
# error is 0.0090082124780481616
# taking Procrustes step
# error is 0.008870591491684723
# taking Procrustes step
# error is 0.0087350729796936422
# taking Procrustes step
# error is 0.008601624821985631
# taking Procrustes step
# error is 0.008470215389179336
# taking Procrustes step
# error is 0.0083408135351019843
# taking Procrustes step
# error is 0.0082133885894121166
# taking Procrustes step
# error is 0.008087910350323739
# taking Procrustes step
# error is 0.0079643490774575585
# taking Procrustes step
# error is 0.007842675484782357
# taking Procrustes step
# error is 0.0077228607336772706
# taking Procrustes step
# error is 0.0076048764261008742
# taking Procrustes step
# error is 0.0074886945978534522
# taking Procrustes step
# error is 0.0073742877119534504
# taking Procrustes step
# error is 0.0072616286521092676
# taking Procrustes step
# error is 0.007150690716292497
# taking Procrustes step
# error is 0.0070414476104074981
# taking Procrustes step
# error is 0.0069338734420653489
# taking Procrustes step
# error is 0.0068279427144376506
# taking Procrustes step
# error is 0.0067236303202207861
# taking Procrustes step
# error is 0.0066209115356813258
# taking Procrustes step
# error is 0.006519762014797671
# taking Procrustes step
# error is 0.0064201577834892068
# taking Procrustes step
# error is 0.0063220752339340726
# taking Procrustes step
# error is 0.0062254911189744428
# taking Procrustes step
# error is 0.0061303825466042126
# taking Procrustes step
# error is 0.006036726974545761
# taking Procrustes step
# error is 0.0059445022049053973
# taking Procrustes step
# error is 0.0058536863789162502
# taking Procrustes step
# error is 0.0057642579717485402
# taking Procrustes step
# error is 0.0056761957874180485
# taking Procrustes step
# error is 0.0055894789537551393
# taking Procrustes step
# error is 0.0055040869174597298
# taking Procrustes step
# error is 0.0054199994392320561
# taking Procrustes step
# error is 0.0053371965889726465
# taking Procrustes step
# error is 0.0052556587410606866
# taking Procrustes step
# error is 0.0051753665696999364
# taking Procrustes step
# error is 0.0050963010443409009
# taking Procrustes step
# error is 0.0050184434251698265
# taking Procrustes step
# error is 0.0049417752586639512
# taking Procrustes step
# error is 0.0048662783732214181
# taking Procrustes step
# error is 0.0047919348748556075
# taking Procrustes step
# error is 0.0047187271429464097
# taking Procrustes step
# error is 0.0046466378260727548
# taking Procrustes step
# error is 0.0045756498378941423
# taking Procrustes step
# error is 0.0045057463531031237
# taking Procrustes step
# error is 0.0044369108034386989
# taking Procrustes step
# error is 0.0043691268737559236
# taking Procrustes step
# error is 0.0043023784981613741
# taking Procrustes step
# error is 0.0042366498562058982
# taking Procrustes step
# error is 0.0041719253691318804
# taking Procrustes step
# error is 0.0041081896961849005
# taking Procrustes step
# error is 0.0040454277309738985
# taking Procrustes step
# error is 0.0039836245978926215
# taking Procrustes step
# error is 0.0039227656485946935
# taking Procrustes step
# error is 0.0038628364585192279
# taking Procrustes step
# error is 0.0038038228234741059
# taking Procrustes step
# error is 0.0037457107562690506
# taking Procrustes step
# error is 0.0036884864833991587
# taking Procrustes step
# error is 0.0036321364417814307
# taking Procrustes step
# error is 0.0035766472755405687
# taking Procrustes step
# error is 0.003522005832841949
# taking Procrustes step
# error is 0.0034681991627751665
# taking Procrustes step
# error is 0.0034152145122846862
# taking Procrustes step
# error is 0.0033630393231481501
# taking Procrustes step
# error is 0.0033116612289965349
# taking Procrustes step
# error is 0.0032610680523867939
# taking Procrustes step
# error is 0.0032112478019136834
# taking Procrustes step
# error is 0.003162188669368161
# taking Procrustes step
# error is 0.0031138790269377319
# taking Procrustes step
# error is 0.0030663074244526695
# taking Procrustes step
# error is 0.0030194625866696379
# taking Procrustes step
# error is 0.0029733334106003331
# taking Procrustes step
# error is 0.0029279089628806215
# taking Procrustes step
# error is 0.0028831784771780251
# taking Procrustes step
# error is 0.0028391313516395386
# taking Procrustes step
# error is 0.0027957571463814741
# taking Procrustes step
# error is 0.0027530455810121329
# taking Procrustes step
# error is 0.002710986532195289
# taking Procrustes step
# error is 0.0026695700312531789
# taking Procrustes step
# error is 0.0026287862618022679
# taking Procrustes step
# error is 0.0025886255574259546
# taking Procrustes step
# error is 0.0025490783993842199
# taking Procrustes step
# error is 0.0025101354143584739
# taking Procrustes step
# error is 0.0024717873722272334
# taking Procrustes step
# error is 0.0024340251838822812
# taking Procrustes step
# error is 0.0023968398990702978
# taking Procrustes step
# error is 0.0023602227042746741
# taking Procrustes step
# error is 0.0023241649206251088
# taking Procrustes step
# error is 0.0022886580018406742
# taking Procrustes step
# error is 0.0022536935322046308
# taking Procrustes step
# error is 0.0022192632245690938
# taking Procrustes step
# error is 0.0021853589183916215
# taking Procrustes step
# error is 0.0021519725778004952
# taking Procrustes step
# error is 0.0021190962896901538
# taking Procrustes step
# error is 0.0020867222618464105
# taking Procrustes step
# error is 0.0020548428210979044
# taking Procrustes step
# error is 0.0020234504114988302
# taking Procrustes step
# error is 0.0019925375925386739
# taking Procrustes step
# error is 0.0019620970373762842
# taking Procrustes step
# error is 0.0019321215311051626
# taking Procrustes step
# error is 0.0019026039690433452
# taking Procrustes step
# error is 0.001873537355048748
# taking Procrustes step
# error is 0.0018449147998613742
# taking Procrustes step
# error is 0.0018167295194702008
# taking Procrustes step
# error is 0.0017889748335060854
# taking Procrustes step
# error is 0.0017616441636569391
# taking Procrustes step
# error is 0.0017347310321098233
# taking Procrustes step
# error is 0.0017082290600149747
# taking Procrustes step
# error is 0.0016821319659747866
# taking Procrustes step
# error is 0.0016564335645529429
# taking Procrustes step
# error is 0.0016311277648112241
# taking Procrustes step
# error is 0.0016062085688634414
# taking Procrustes step
# error is 0.001581670070455064
# taking Procrustes step
# error is 0.0015575064535633309
# taking Procrustes step
# error is 0.0015337119910180529
# taking Procrustes step
# error is 0.0015102810431450516
# taking Procrustes step
# error is 0.0014872080564285195
# taking Procrustes step
# error is 0.0014644875621958558
# taking Procrustes step
# error is 0.0014421141753201625
# taking Procrustes step
# error is 0.0014200825929454608
# taking Procrustes step
# error is 0.0013983875932287414
# taking Procrustes step
# error is 0.0013770240341021795
# taking Procrustes step
# error is 0.0013559868520549286
# taking Procrustes step
# error is 0.0013352710609330282
# taking Procrustes step
# error is 0.0013148717507569848
# taking Procrustes step
# error is 0.001294784086559363
# taking Procrustes step
# error is 0.0012750033072364676
# taking Procrustes step
# error is 0.0012555247244224767
# taking Procrustes step
# error is 0.0012363437213763729
# taking Procrustes step
# error is 0.0012174557518890878
# taking Procrustes step
# error is 0.0011988563392043604
# taking Procrustes step
# error is 0.001180541074959307
# taking Procrustes step
# error is 0.0011625056181386959
# taking Procrustes step
# error is 0.0011447456940457603
# taking Procrustes step
# error is 0.0011272570932901098
# taking Procrustes step
# error is 0.001110035670788864
# taking Procrustes step
# error is 0.0010930773447850562
# taking Procrustes step
# error is 0.0010763780958798258
# taking Procrustes step
# error is 0.0010599339660796881
# taking Procrustes step
# error is 0.001043741057858656
# taking Procrustes step
# error is 0.0010277955332341009
# taking Procrustes step
# error is 0.0010120936128575652
# taking Procrustes step
# error is 0.00099663157511885639
# taking Procrustes step
# error is 0.00098140575526338251
# taking Procrustes step
# error is 0.00096641254452455808
# taking Procrustes step
# error is 0.00095164838926776909
# taking Procrustes step
# error is 0.00093710979014801537
# taking Procrustes step
# error is 0.00092279330128122847
# taking Procrustes step
# error is 0.00090869552942656991
# taking Procrustes step
# error is 0.00089481313318328694
# taking Procrustes step
# error is 0.00088114282219753739
# taking Procrustes step
# error is 0.00086768135638348905
# taking Procrustes step
# error is 0.00085442554515496589
# taking Procrustes step
# error is 0.00084137224666917647
# taking Procrustes step
# error is 0.00082851836708221075
# taking Procrustes step
# error is 0.00081586085981574178
# taking Procrustes step
# error is 0.00080339672483470078
# taking Procrustes step
# error is 0.00079112300793658294
# taking Procrustes step
# error is 0.00077903680005092437
# taking Procrustes step
# error is 0.00076713523654993584
# taking Procrustes step
# error is 0.00075541549656975055
# taking Procrustes step
# error is 0.00074387480234148345
# taking Procrustes step
# error is 0.00073251041853281248
# taking Procrustes step
# error is 0.00072131965160036546
# taking Procrustes step
# error is 0.00071029984915009427
# taking Procrustes step
# error is 0.00069944839930999824
# taking Procrustes step
# error is 0.00068876273010996867
# taking Procrustes step
# error is 0.00067824030887265812
# taking Procrustes step
# error is 0.00066787864161328182
# taking Procrustes step
# error is 0.00065767527244821116
# taking Procrustes step
# error is 0.00064762778301317753
# taking Procrustes step
# error is 0.00063773379188983141
# taking Procrustes step
# error is 0.00062799095404138412
# taking Procrustes step
# error is 0.00061839696025695686
# taking Procrustes step
# error is 0.00060894953660408388
# taking Procrustes step
# error is 0.00059964644388978638
# taking Procrustes step
# error is 0.00059048547712976839
# taking Procrustes step
# error is 0.00058146446502611989
# taking Procrustes step
# error is 0.00057258126945236424
# taking Procrustes step
# error is 0.00056383378494662562
# taking Procrustes step
# error is 0.00055521993821298031
# taking Procrustes step
# error is 0.00054673768762967168
# taking Procrustes step
# error is 0.0005383850227655201
# taking Procrustes step
# error is 0.00053015996390310771
# taking Procrustes step
# error is 0.00052206056156983867
# taking Procrustes step
# error is 0.00051408489607570273
# taking Procrustes step
# error is 0.00050623107705826222
# taking Procrustes step
# error is 0.00049849724303481491
# taking Procrustes step
# error is 0.00049088156096100007
# taking Procrustes step
# error is 0.00048338222579629852
# taking Procrustes step
# error is 0.00047599746007643623
# taking Procrustes step
# error is 0.00046872551349184678
# taking Procrustes step
# error is 0.0004615646624730767
# taking Procrustes step
# error is 0.00045451320978196538
# taking Procrustes step
# error is 0.00044756948410957744
# taking Procrustes step
# error is 0.00044073183968012191
# taking Procrustes step
# error is 0.00043399865586066336
# taking Procrustes step
# error is 0.00042736833677732604
# taking Procrustes step
# error is 0.00042083931093654452
# taking Procrustes step
# error is 0.00041441003085315714
# taking Procrustes step
# error is 0.0004080789726832268
# taking Procrustes step
# error is 0.0004018446358631545
# taking Procrustes step
# error is 0.00039570554275362139
# taking Procrustes step
# error is 0.00038966023828993488
# taking Procrustes step
# error is 0.00038370728963654495
# taking Procrustes step
# error is 0.00037784528584789448
# taking Procrustes step
# error is 0.00037207283753391059
# taking Procrustes step
# error is 0.00036638857653026633
# taking Procrustes step
# error is 0.00036079115557495392
# taking Procrustes step
# error is 0.00035527924798810099
# taking Procrustes step
# error is 0.00034985154735800396
# taking Procrustes step
# error is 0.00034450676723146408
# taking Procrustes step
# error is 0.00033924364080863644
# taking Procrustes step
# error is 0.00033406092064302537
# taking Procrustes step
# error is 0.00032895737834572872
# taking Procrustes step
# error is 0.00032393180429425003
# taking Procrustes step
# error is 0.00031898300734584177
# taking Procrustes step
# error is 0.00031410981455522332
# taking Procrustes step
# error is 0.00030931107089643558
# taking Procrustes step
# error is 0.00030458563898926738
# taking Procrustes step
# error is 0.00029993239882955742
# taking Procrustes step
# error is 0.00029535024752372758
# taking Procrustes step
# error is 0.00029083809902743265
# taking Procrustes step
# error is 0.00028639488388810885
# taking Procrustes step
# error is 0.00028201954899156146
# taking Procrustes step
# error is 0.00027771105731237201
# taking Procrustes step
# error is 0.00027346838766788853
# taking Procrustes step
# error is 0.00026929053447643641
# taking Procrustes step
# error is 0.0002651765075190055
# taking Procrustes step
# error is 0.00026112533170420633
# taking Procrustes step
# error is 0.00025713604683759623
# taking Procrustes step
# error is 0.0002532077073938015
# taking Procrustes step
# error is 0.00024933938229250842
# taking Procrustes step
# error is 0.0002455301546777972
# taking Procrustes step
# error is 0.00024177912170078971
# taking Procrustes step
# error is 0.00023808539430570356
# taking Procrustes step
# error is 0.00023444809701912594
# taking Procrustes step
# error is 0.00023086636774246482
# taking Procrustes step
# error is 0.00022733935754764615
# taking Procrustes step
# error is 0.00022386623047594652
# taking Procrustes step
# error is 0.00022044616333976734
# taking Procrustes step
# error is 0.00021707834552761289
# taking Procrustes step
# error is 0.00021376197881195147
# taking Procrustes step
# error is 0.00021049627715991813
# taking Procrustes step
# error is 0.0002072804665471804
# taking Procrustes step
# error is 0.000204113784774317
# taking Procrustes step
# error is 0.00020099548128628956
# taking Procrustes step
# error is 0.00019792481699447813
# taking Procrustes step
# error is 0.00019490106410152152
# taking Procrustes step
# error is 0.00019192350592884785
# taking Procrustes step
# error is 0.00018899143674676794
# taking Procrustes step
# error is 0.00018610416160722877
# taking Procrustes step
# error is 0.00018326099617910059
# taking Procrustes step
# error is 0.00018046126658591985
# taking Procrustes step
# error is 0.00017770430924631092
# taking Procrustes step
# error is 0.00017498947071655882
# taking Procrustes step
# error is 0.00017231610753577165
# taking Procrustes step
# error is 0.00016968358607345155
# taking Procrustes step
# error is 0.00016709128237919592
# taking Procrustes step
# error is 0.00016453858203494711
# taking Procrustes step
# error is 0.00016202488000916895
# taking Procrustes step
# error is 0.00015954958051365056
# taking Procrustes step
# error is 0.00015711209686216458
# taking Procrustes step
# error is 0.0001547118513314645
# taking Procrustes step
# error is 0.00015234827502435156
# taking Procrustes step
# error is 0.00015002080773482128
# taking Procrustes step
# error is 0.00014772889781529085
# taking Procrustes step
# error is 0.00014547200204586888
# taking Procrustes step
# error is 0.00014324958550553481
# taking Procrustes step
# error is 0.00014106112144548103
# taking Procrustes step
# error is 0.00013890609116414327
# taking Procrustes step
# error is 0.00013678398388428391
# taking Procrustes step
# error is 0.00013469429663202768
# taking Procrustes step
# error is 0.00013263653411750998
# taking Procrustes step
# error is 0.00013061020861755628
# taking Procrustes step
# error is 0.00012861483986010224
# taking Procrustes step
# error is 0.00012664995491030542
# taking Procrustes step
# error is 0.0001247150880584937
# taking Procrustes step
# error is 0.00012280978070979272
# taking Procrustes step
# error is 0.00012093358127536489
# taking Procrustes step
# error is 0.00011908604506545937
# taking Procrustes step
# error is 0.00011726673418396224
# taking Procrustes step
# error is 0.00011547521742462389
# taking Procrustes step
# error is 0.00011371107016884089
# taking Procrustes step
# error is 0.00011197387428503595
# taking Procrustes step
# error is 0.00011026321802957741
# taking Procrustes step
# error is 0.00010857869594910006
# taking Procrustes step
# error is 0.00010691990878448141
# taking Procrustes step
# error is 0.00010528646337622143
# taking Procrustes step
# error is 0.00010367797257118662
# taking Procrustes step
# error is 0.00010209405513093044
# taking Procrustes step
# error is 0.00010053433564126257
# taking Procrustes step
# error is 9.8998444423313949e-05

# %%
scatter(proc.sources[:,0,:].flatten(), proc.sources[:,1,:].flatten())

# %% [markdown]
# We need to define a few special landmarks for us to be able to figure out what direction
# the faces is orientated in. For these medical landmarks we have:
#
# * $l_{16}$ - Centre of forehead
# * $l_{28}$ - Centre of lower chin
# * $l_{31}$ - Centre of bottom lip
# * $l_{32}$ - bottom of right ear
# * $l_{34}$ - bottom of left ear
#
# The approach we take is as follows:
#
# 1. Generate a vector for the vetical alignment $v_{up} = l_{16} - l_{28}$
# 2. Generate a landmark at the midpoint in the back of the head $l_{back} = (l_{32} + l_{34})/2$
# 3. Generate a vector pointing towards the camera: $v_{front} = l_{31} - l_{back}$

# %%
face.view_location_of_vertices(face.lm)
