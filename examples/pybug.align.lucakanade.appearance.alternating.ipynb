# %% [markdown]
# # Fit an AAM to an Input Images
# ##### Version 0.1
#
# ### 1. Load the Data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset.

# %%
from pybug.io import auto_import
from pybug.landmark.labels import  labeller, ibug_68_points, ibug_68_contour, ibug_68_trimesh

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/vol/atlas/databases/lfpw/test/' + '*.png')

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points)
labeller(images, 'PTS', ibug_68_contour)
labeller(images, 'PTS', ibug_68_trimesh)

from pybug.shape import PointCloud

points = [img.landmarks['PTS'].all_landmarks.points - 1  for img in images]
shapes = [PointCloud(p) for p in points]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x7d6bd10> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d759d0> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75a10> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75a50> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75a90> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75ad0> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75b10> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75b50> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75b90> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75bd0> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75c10> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75c50> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75c90> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75cd0> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75d10> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75d50> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75d90> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75dd0> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75e10> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75e50> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75e90> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75ed0> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75f10> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75f50> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75f90> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d75fd0> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83050> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83090> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d830d0> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83110> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83150> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83190> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d831d0> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83210> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83250> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83290> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d832d0> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83310> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83350> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83390> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d833d0> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83410> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83450> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83490> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d834d0> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83510> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83550> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83590> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d835d0> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83610> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83650> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83690> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d836d0> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83710> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83750> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83790> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d837d0> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83810> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83850> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83890> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d838d0> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83910> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83950> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83990> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d839d0> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83a10> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83a50> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83a90> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83ad0> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83b10> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83b50> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83b90> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83bd0> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83c10> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83c50> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83c90> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83cd0> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83d10> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83d50> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83d90> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83dd0> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83e10> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83e50> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83e90> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83ed0> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83f10> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83f50> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83f90> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d83fd0> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c050> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c090> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c0d0> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c110> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c150> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c190> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c1d0> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c210> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c250> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c290> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c2d0> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c310> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c350> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c390> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c3d0> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c410> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c450> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c490> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c4d0> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c510> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c550> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c590> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c5d0> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c610> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c650> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c690> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c6d0> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c710> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c750> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c790> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c7d0> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c810> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c850> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c890> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c8d0> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c910> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c950> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c990> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8c9d0> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ca10> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ca50> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ca90> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cad0> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cb10> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cb50> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cb90> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cbd0> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cc10> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cc50> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cc90> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ccd0> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cd10> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cd50> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cd90> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cdd0> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ce10> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ce50> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ce90> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8ced0> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cf10> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cf50> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cf90> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d8cfd0> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91050> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91090> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d910d0> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91110> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91150> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91190> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d911d0> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91210> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91250> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91290> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d912d0> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91310> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91350> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91390> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d913d0> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91410> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91450> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91490> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d914d0> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91510> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91550> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91590> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d915d0> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91610> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91650> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91690> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d916d0> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91710> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91750> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91790> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d917d0> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91810> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91850> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91890> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d918d0> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91910> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91950> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91990> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d919d0> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91a10> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91a50> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91a90> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91ad0> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91b10> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91b50> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91b90> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91bd0> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91c10> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91c50> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91c90> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91cd0> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91d10> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91d50> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91d90> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91dd0> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91e10> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91e50> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91e90> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91ed0> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91f10> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91f50> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91f90> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d91fd0> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97050> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97090> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d970d0> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97110> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97150> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97190> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d971d0> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97210> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7d97250> (224 of 224)
# /vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/mayavi/preferences/preference_manager.py:24: UserWarning: Module PIL was already imported from /usr/lib/python2.7/dist-packages/PIL/__init__.pyc, but /vol/atlas/homes/ja310/.virtualenvs/pybug/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Use **pickle** to load a previously build *AAM*

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa', "rb"))

reference_frame = aam["template"]
appearance_model = aam["appearance_model"]
shape_model = aam["shape_model_1"]

# %% [markdown]
# ### 2. Fit
#
# We start randomly selecting an image to fit.

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[ind].as_greyscale()
test_shape = shapes[ind]

# %% [markdown]
# Visualize the ground truth landmarks and warped appearance for the selected test image.

# %%
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.warp import scipy_warp

source = reference_frame.landmarks['PTS'].all_landmarks
trilist = reference_frame.get_landmark_set('ibug_68_trimesh').landmark_dict['tri'].trilist
template_pwa = PiecewiseAffineTransform(source.points, test_shape.points, trilist)
template = scipy_warp(test_image, reference_frame, template_pwa)

test_image.add_landmark_set("ground_truth", {"ground_truth": test_shape})
test_image.get_landmark_set("ground_truth").with_label('ground_truth').view()

template.add_landmark_set('reference', {'reference': source})
template.get_landmark_set('reference').with_label('reference').view()

# %% [markdown]
# Then we build a dummy Similarity Transform and a dummy Statistically Driven Transform

# %%
from pybug.transform.statisticallydriven import StatisticallyDrivenTransform
from pybug.transform.affine import SimilarityTransform
from scipy.spatial import Delaunay

def pwa_constructor(src_landmarks, tgt_landmarks):
    tri = Delaunay(src_landmarks)
    return PiecewiseAffineTransform(src_landmarks, tgt_landmarks, tri.simplices)

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

dummy_statistically_driven_transform = StatisticallyDrivenTransform(shape_model, pwa_constructor,
                                                                    source=source, global_transform=global_transform,
                                                                    composition='both')

# %% [markdown]
# Build the "fitter" object.

# %%
from pybug.align.lucaskanade.residual import LSIntensity, GradientImages
from pybug.align.lucaskanade.base import AlternatingAppearanceForwardAdditive, AlternatingAppearanceForwardCompositional, AlternatingAppearanceInverseCompositional

residual = LSIntensity()
afa = AlternatingAppearanceForwardAdditive(appearance_model, residual, dummy_statistically_driven_transform)
afc = AlternatingAppearanceForwardCompositional(appearance_model, residual, dummy_statistically_driven_transform)
aic = AlternatingAppearanceInverseCompositional(appearance_model, residual, dummy_statistically_driven_transform)

# %% [markdown]
# Initialize by scaling and translating the shape model mean using the scale and translation parameters from the ground truth shape.

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# estimate similarity transform
similarity_transform = SimilarityTransform.estimate(shape_model.mean.points, test_shape.points)
global_parameters = similarity_transform.as_vector()
# kill rotation
global_parameters[1] = 0
# add random gaussian noise to the ground truth parameters
#global_parameters += 0.1 * np.random.randn(4) 

global_transform = SimilarityTransform.from_vector(global_parameters)

aligned_test_points = global_transform.inverse.apply(test_shape.points)
aligned_test_shape = PointCloud(aligned_test_points)
weights = shape_model.project(aligned_test_shape)

initial_parameters = np.concatenate([global_parameters, np.zeros_like(weights)])

# %% [markdown]
# Check the correctness of the initialization.

# %%
initial_transform = dummy_statistically_driven_transform.from_vector(initial_parameters)
initial_warped_image = scipy_warp(test_image, template, initial_transform)

test_image.add_landmark_set("initial", {"initial": initial_transform.target})
test_image.get_landmark_set("initial").view()

initial_warped_image.add_landmark_set('reference', {'reference': source})
initial_warped_image.get_landmark_set('reference').with_label('reference').view()

# %% [markdown]
# Fit using the 3 curent methods for image alignment.

# %%
optimal_transform_1 = afa.align(test_image, initial_parameters, max_iters=60)
optimal_transform_2 = afc.align(test_image, initial_parameters, max_iters=60)
optimal_transform_3 = aic.align(test_image, initial_parameters, max_iters=60)

# %% [markdown]
# Visualize the results.

# %%
fitted_appearance_1 = scipy_warp(test_image, template, optimal_transform_1)
fitted_appearance_2 = scipy_warp(test_image, template, optimal_transform_2)
fitted_appearance_3 = scipy_warp(test_image, template, optimal_transform_3)

test_image.add_landmark_set('fitting_results', {'afa': optimal_transform_1.target,
                                                'afc': optimal_transform_2.target,
                                                'aic': optimal_transform_3.target})
test_image.get_landmark_set('fitting_results').with_label('afa').view()
test_image.get_landmark_set('fitting_results').with_label('afc').view()
test_image.get_landmark_set('fitting_results').with_label('aic').view()

fitted_appearance_1.add_landmark_set('reference', {'reference': source})
fitted_appearance_1.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))
fitted_appearance_2.add_landmark_set('reference', {'reference': source})
fitted_appearance_2.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))
fitted_appearance_3.add_landmark_set('reference', {'reference': source})
fitted_appearance_3.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc'
