# %% [markdown]
# # AAMs for image alignment
#
# ### 1. Load the data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset:

# %%
from pybug.io import auto_import
from pybug.landmark.labels import  (labeller, ibug_68_points, 
                                    ibug_68_contour, ibug_68_trimesh)
from pybug.shape import PointCloud

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/vol/atlas/databases/lfpw/test/' + '*.png')

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points)
labeller(images, 'PTS', ibug_68_contour)
labeller(images, 'PTS', ibug_68_trimesh)

# Extract shape data. -1 because the annotation are 1 based
points = [img.landmarks['PTS'].all_landmarks.points - 1  for img in images]
shapes = [PointCloud(p) for p in points]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x205dc890> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205dc0d0> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205dc1d0> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x68984550> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b890> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b390> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658bd90> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658ba90> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b790> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b410> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658bb10> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b290> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658bd10> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658be10> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b590> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658bf90> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b610> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b990> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658bb90> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658be90> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b210> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b810> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2658b490> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x6898ed50> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205cb9d0> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205cb8d0> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x493fd990> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x493fd310> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x68986e50> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x68974b10> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x68974c10> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265b3050> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93dc90> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93de90> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93d490> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93d410> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93db10> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93d210> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93dc10> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc93d810> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265940d0> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594750> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265945d0> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594150> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594a50> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265944d0> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594350> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594550> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594850> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594fd0> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265948d0> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594ed0> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594d50> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265947d0> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594250> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594ad0> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594bd0> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594b50> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594450> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265949d0> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594c50> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594e50> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265942d0> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594650> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594950> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594050> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26594cd0> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265941d0> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265946d0> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c290> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657cb10> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657cf90> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657cd10> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c710> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657ce10> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c590> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c810> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c910> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c510> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657ce90> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657ca90> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c190> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c110> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657cc90> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c790> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x2657c390> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x6898c690> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x6898c790> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205c8310> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205c8210> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x642e3990> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x642e34d0> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x642e39d0> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x642e37d0> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x642e3a90> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x642e32d0> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909fd0> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909750> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909b50> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269097d0> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909250> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909d50> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909150> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909cd0> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269092d0> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909950> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269099d0> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269098d0> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909ed0> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909f50> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269095d0> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269093d0> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909c50> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909550> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909450> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269090d0> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909ad0> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909bd0> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909050> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909e50> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269094d0> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909a50> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909850> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x269096d0> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909650> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909dd0> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26909350> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x49426b10> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x49426cd0> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x494265d0> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x49426110> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x494263d0> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x49426510> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x49426fd0> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3f50> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3650> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3ed0> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3250> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3150> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a39d0> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3b50> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265a3350> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584850> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584350> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584cd0> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584ed0> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584f50> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265845d0> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584c50> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265847d0> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584050> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265844d0> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584750> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265841d0> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584bd0> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584250> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584ad0> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265849d0> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584d50> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584150> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265840d0> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584dd0> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584950> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265842d0> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584550> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265846d0> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584fd0> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265848d0> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584450> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584650> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584b50> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265843d0> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x26584a50> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x689af8d0> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x689af9d0> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265aa610> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x265aaa10> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205fd590> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x205fdad0> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954b90> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954410> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954710> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9542d0> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954dd0> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9545d0> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954e10> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954990> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954e50> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9548d0> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954bd0> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954c50> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954c90> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954650> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954c10> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954cd0> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954090> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954290> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954510> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954890> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954f10> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954610> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9541d0> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954ad0> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954e90> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954d90> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9540d0> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954310> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954190> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954950> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954490> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954fd0> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954790> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954d50> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954ed0> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954750> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954590> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954850> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954150> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954f90> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954390> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9543d0> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954a90> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc9549d0> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0xc954910> (224 of 224)

# %% [markdown]
# Use **pickle** to load a previously build *AAM*:

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa', "rb"))

reference_frame = aam["template"]
appearance_model = aam["appearance_model"]
shape_model = aam["shape_model_1"]

# %% [markdown]
# ### 2. Fit
#
# Randomly select an image to fit:

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[ind].as_greyscale()
test_shape = shapes[ind]

# %% [markdown]
# Because we will not be using the Appearance Model yet, we need to build the appropiate template:

# %%
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.warp import scipy_warp

source = reference_frame.landmarks['PTS'].all_landmarks
trilist = reference_frame.get_landmark_set('ibug_68_trimesh').landmark_dict['tri'].trilist
template_pwa = PiecewiseAffineTransform(source.points, test_shape.points, trilist)
template = scipy_warp(test_image, reference_frame, template_pwa)

test_image.add_landmark_set("ground_truth", {"ground_truth": test_shape})
test_image.get_landmark_set("ground_truth").with_label('ground_truth').view()
gcf().set_size_inches((10,10))

template.add_landmark_set('reference', {'reference': source})
template.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %% [markdown]
# Build Statistically Driven Transform using the AAM's shape model and Piece Wise Affine (PWA) warps:

# %%
from pybug.transform.statisticallydriven import StatisticallyDrivenTransform
from pybug.transform.affine import SimilarityTransform
from scipy.spatial import Delaunay

def pwa_constructor(src_landmarks, tgt_landmarks):
    tri = Delaunay(src_landmarks)
    return PiecewiseAffineTransform(src_landmarks, tgt_landmarks, tri.simplices)

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

stat_driven_transform = StatisticallyDrivenTransform(shape_model, pwa_constructor,
                                                     source=source, 
                                                     global_transform=global_transform)

# %% [markdown]
# Build three "fitter" objects using the three variations of the Project Out algorithm:

# %%
from pybug.align.lucaskanade.residual import LSIntensity
from pybug.align.lucaskanade.image import (ImageForwardAdditive,
                                           ImageForwardCompositional,
                                           ImageInverseCompositional)
# standard Least Squares Residual
residual = LSIntensity()

# forward additive
fa = ImageForwardAdditive(template, residual, stat_driven_transform)
# forwad compositional
fc = ImageForwardCompositional(template, residual, stat_driven_transform)
# inverse compositional
ic = ImageInverseCompositional(template, residual, stat_driven_transform)

# %% [markdown]
# Initialize the fitting procedure by perturbing the true scale and translation parameters of the manually annotated shape:

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# estimate the true similarity transform
similarity_transform = SimilarityTransform.estimate(shape_model.mean.points, 
                                                    test_shape.points)

global_parameters = similarity_transform.as_vector()
# kill rotation
global_parameters[1] = 0
# add random gaussian noise to the ground truth parameters
global_parameters += 0.1 * np.random.randn(4) 

global_transform = SimilarityTransform.from_vector(global_parameters)

aligned_test_points = global_transform.inverse.apply(test_shape.points)
aligned_test_shape = PointCloud(aligned_test_points)
weights = shape_model.project(aligned_test_shape)

initial_parameters = np.concatenate([global_parameters, np.zeros_like(weights)])

# %% [markdown]
# Check the correctness of the initialization:

# %%
initial_transform = stat_driven_transform.from_vector(initial_parameters)
initial_warped_image = scipy_warp(test_image, template, initial_transform)

test_image.add_landmark_set("initial", {"initial": initial_transform.target})
test_image.get_landmark_set("initial").view()
gcf().set_size_inches((10,10))

initial_warped_image.add_landmark_set('reference', {'reference': source})
initial_warped_image.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %% [markdown]
# Fit the image using all three different methods:

# %%
# %time optimal_transform_1 = fa.align(test_image, initial_parameters, max_iters=50)
# %time optimal_transform_2 = fc.align(test_image, initial_parameters, max_iters=50)
# %time optimal_transform_3 = ic.align(test_image, initial_parameters, max_iters=50)
# Out:
# CPU times: user 11.6 s, sys: 0 ns, total: 11.6 s
# Wall time: 11.6 s
# CPU times: user 5.57 s, sys: 0 ns, total: 5.57 s
# Wall time: 5.59 s
# CPU times: user 5.12 s, sys: 4 ms, total: 5.13 s
# Wall time: 5.15 s

# %% [markdown]
# Visualize the results:

# %%
fitted_appearance_1 = scipy_warp(test_image, template, optimal_transform_1)
fitted_appearance_2 = scipy_warp(test_image, template, optimal_transform_2)
fitted_appearance_3 = scipy_warp(test_image, template, optimal_transform_3)

fitted_appearance_1.add_landmark_set('reference', {'reference': source})
fitted_appearance_1.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

fitted_appearance_2.add_landmark_set('reference', {'reference': source})
fitted_appearance_2.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

fitted_appearance_3.add_landmark_set('reference', {'reference': source})
fitted_appearance_3.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %%
test_image.add_landmark_set('fitting_results', {'fa': optimal_transform_1.target,
                                                'fc': optimal_transform_2.target,
                                                'ic': optimal_transform_3.target})

test_image.get_landmark_set('fitting_results').with_label('fa').view()
gcf().set_size_inches((10,10))

test_image.get_landmark_set('fitting_results').with_label('fc').view()
gcf().set_size_inches((10,10))

test_image.get_landmark_set('fitting_results').with_label('ic').view()
gcf().set_size_inches((10,10))
