# %% [markdown]
# # AAMs for image alignment
#
# ### 1. Load the data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset:

# %%
from pybug.io import auto_import
from pybug.landmark.labels import  (labeller, ibug_68_points, 
                                    ibug_68_contour, ibug_68_trimesh)
from pybug.shape import PointCloud

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/vol/atlas/databases/lfpw/test/' + '*.png')

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points)
labeller(images, 'PTS', ibug_68_contour)
labeller(images, 'PTS', ibug_68_trimesh)

# Extract shape data. -1 because the annotation are 1 based
points = [img.landmarks['PTS'].all_landmarks.points - 1  for img in images]
shapes = [PointCloud(p) for p in points]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d810> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d890> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d8d0> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d910> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d950> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d990> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5d9d0> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5da10> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5da50> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5da90> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dad0> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5db10> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5db50> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5db90> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dbd0> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dc10> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dc50> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dc90> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dcd0> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dd10> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dd50> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dd90> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5ddd0> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5de10> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5de50> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5de90> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5ded0> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5df10> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5df50> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5df90> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a5dfd0> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b050> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b090> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b0d0> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b110> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b150> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b190> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b1d0> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b210> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b250> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b290> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b2d0> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b310> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b350> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b390> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b3d0> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b410> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b450> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b490> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b4d0> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b510> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b550> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b590> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b5d0> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b610> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b650> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b690> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b6d0> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b710> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b750> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b790> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b7d0> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b810> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b850> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b890> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b8d0> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b910> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b950> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b990> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6b9d0> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6ba10> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6ba50> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6ba90> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bad0> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bb10> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bb50> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bb90> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bbd0> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bc10> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bc50> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bc90> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bcd0> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bd10> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bd50> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bd90> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bdd0> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6be10> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6be50> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6be90> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bed0> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bf10> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bf50> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bf90> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a6bfd0> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73050> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73090> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a730d0> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73110> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73150> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73190> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a731d0> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73210> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73250> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73290> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a732d0> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73310> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73350> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73390> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a733d0> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73410> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73450> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73490> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a734d0> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73510> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73550> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73590> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a735d0> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73610> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73650> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73690> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a736d0> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73710> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73750> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73790> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a737d0> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73810> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73850> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73890> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a738d0> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73910> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73950> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73990> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a739d0> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73a10> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73a50> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73a90> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73ad0> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73b10> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73b50> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73b90> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73bd0> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73c10> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73c50> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73c90> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73cd0> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73d10> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73d50> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73d90> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73dd0> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73e10> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73e50> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73e90> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73ed0> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73f10> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73f50> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73f90> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a73fd0> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78050> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78090> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a780d0> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78110> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78150> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78190> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a781d0> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78210> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78250> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78290> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a782d0> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78310> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78350> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78390> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a783d0> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78410> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78450> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78490> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a784d0> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78510> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78550> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78590> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a785d0> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78610> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78650> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78690> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a786d0> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78710> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78750> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78790> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a787d0> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78810> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78850> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78890> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a788d0> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78910> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78950> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78990> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a789d0> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78a10> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78a50> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78a90> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78ad0> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78b10> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78b50> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78b90> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78bd0> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78c10> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78c50> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78c90> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78cd0> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78d10> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78d50> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78d90> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78dd0> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78e10> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78e50> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78e90> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78ed0> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78f10> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78f50> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78f90> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a78fd0> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a7d050> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a7d090> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a7d0d0> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x8a7d110> (224 of 224)
# /vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/mayavi/preferences/preference_manager.py:24: UserWarning: Module PIL was already imported from /usr/lib/python2.7/dist-packages/PIL/__init__.pyc, but /vol/atlas/homes/ja310/.virtualenvs/pybug/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Use **pickle** to load a previously build *AAM*:

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa', "rb"))

reference_frame = aam["template"]
appearance_model = aam["appearance_model"]
shape_model = aam["shape_model_1"]

# %% [markdown]
# ### 2. Fit
#
# Randomly select an image to fit:

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[ind].as_greyscale()
test_shape = shapes[ind]

# %% [markdown]
# Because we will not be using the Appearance Model yet, we need to build the appropiate template:

# %%
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.warp import scipy_warp

source = reference_frame.landmarks['PTS'].all_landmarks
trilist = reference_frame.get_landmark_set('ibug_68_trimesh').landmark_dict['tri'].trilist
template_pwa = PiecewiseAffineTransform(source.points, test_shape.points, trilist)
template = scipy_warp(test_image, reference_frame, template_pwa)

test_image.add_landmark_set("ground_truth", {"ground_truth": test_shape})
test_image.get_landmark_set("ground_truth").with_label('ground_truth').view()
gcf().set_size_inches((10,10))

template.add_landmark_set('reference', {'reference': source})
template.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %% [markdown]
# Build Statistically Driven Transform using the AAM's shape model and Piece Wise Affine (PWA) warps:

# %%
from pybug.transform.statisticallydriven import StatisticallyDrivenTransform
from pybug.transform.affine import SimilarityTransform
from scipy.spatial import Delaunay

def pwa_constructor(src_landmarks, tgt_landmarks):
    tri = Delaunay(src_landmarks)
    return PiecewiseAffineTransform(src_landmarks, tgt_landmarks, tri.simplices)

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

stat_driven_transform = StatisticallyDrivenTransform(shape_model, pwa_constructor,
                                                     source=source, 
                                                     global_transform=global_transform)

# %% [markdown]
# Build three "fitter" objects using the three variations of the Project Out algorithm:

# %%
from pybug.align.lucaskanade.residual import LSIntensity
from pybug.align.lucaskanade.image import (ImageForwardAdditive,
                                           ImageForwardCompositional,
                                           ImageInverseCompositional)
# standard Least Squares Residual
residual = LSIntensity()

# forward additive
fa = ImageForwardAdditive(template, residual, stat_driven_transform)
# forwad compositional
fc = ImageForwardCompositional(template, residual, stat_driven_transform)
# inverse compositional
ic = ImageInverseCompositional(template, residual, stat_driven_transform)

# %% [markdown]
# Initialize the fitting procedure by perturbing the true scale and translation parameters of the manually annotated shape:

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# estimate the true similarity transform
similarity_transform = SimilarityTransform.estimate(shape_model.mean.points, 
                                                    test_shape.points)

global_parameters = similarity_transform.as_vector()
# kill rotation
global_parameters[1] = 0
# add random gaussian noise to the ground truth parameters
global_parameters += 0.1 * np.random.randn(4) 

global_transform = SimilarityTransform.from_vector(global_parameters)

aligned_test_points = global_transform.inverse.apply(test_shape.points)
aligned_test_shape = PointCloud(aligned_test_points)
weights = shape_model.project(aligned_test_shape)

initial_parameters = np.concatenate([global_parameters, np.zeros_like(weights)])

# %% [markdown]
# Check the correctness of the initialization:

# %%
initial_transform = stat_driven_transform.from_vector(initial_parameters)
initial_warped_image = scipy_warp(test_image, template, initial_transform)

test_image.add_landmark_set("initial", {"initial": initial_transform.target})
test_image.get_landmark_set("initial").view()
gcf().set_size_inches((10,10))

initial_warped_image.add_landmark_set('reference', {'reference': source})
initial_warped_image.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %% [markdown]
# Fit the image using all three different methods:

# %%
# %time optimal_transform_1 = fa.align(test_image, initial_parameters, max_iters=50)
# %time optimal_transform_2 = fc.align(test_image, initial_parameters, max_iters=50)
# %time optimal_transform_3 = ic.align(test_image, initial_parameters, max_iters=50)
# Out:
# CPU times: user 15.2 s, sys: 728 ms, total: 16 s
# Wall time: 16 s
# CPU times: user 5.36 s, sys: 380 ms, total: 5.74 s
# Wall time: 5.76 s
# CPU times: user 4.91 s, sys: 404 ms, total: 5.32 s
# Wall time: 5.34 s

# %% [markdown]
# Visualize the results:

# %%
fitted_appearance_1 = scipy_warp(test_image, template, optimal_transform_1)
fitted_appearance_2 = scipy_warp(test_image, template, optimal_transform_2)
fitted_appearance_3 = scipy_warp(test_image, template, optimal_transform_3)

fitted_appearance_1.add_landmark_set('reference', {'reference': source})
fitted_appearance_1.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

fitted_appearance_2.add_landmark_set('reference', {'reference': source})
fitted_appearance_2.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

fitted_appearance_3.add_landmark_set('reference', {'reference': source})
fitted_appearance_3.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %%
test_image.add_landmark_set('fitting_results', {'fa': optimal_transform_1.target,
                                                'fc': optimal_transform_2.target,
                                                'ic': optimal_transform_3.target})

test_image.get_landmark_set('fitting_results').with_label('fa').view()
gcf().set_size_inches((10,10))

test_image.get_landmark_set('fitting_results').with_label('fc').view()
gcf().set_size_inches((10,10))

test_image.get_landmark_set('fitting_results').with_label('ic').view()
gcf().set_size_inches((10,10))
