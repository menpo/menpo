# %% [markdown]
# # Fit an AAM to an Input Images
# ##### Version 0.1
#
# ### 1. Load the Data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset.

# %%
from pybug.io import auto_import
from pybug.landmark.labels import  labeller, ibug_68_points, ibug_68_contour, ibug_68_trimesh

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/vol/atlas/databases/lfpw/test/' + '*.png')

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points)
labeller(images, 'PTS', ibug_68_contour)
labeller(images, 'PTS', ibug_68_trimesh)

from pybug.shape import PointCloud

points = [img.landmarks['PTS'].all_landmarks.points - 1  for img in images]
shapes = [PointCloud(p) for p in points]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x80d3d10> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dd9d0> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dda10> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dda50> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dda90> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddad0> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddb10> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddb50> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddb90> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddbd0> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddc10> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddc50> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddc90> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddcd0> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddd10> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddd50> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddd90> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dddd0> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dde10> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dde50> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dde90> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80dded0> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddf10> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddf50> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddf90> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ddfd0> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb050> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb090> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb0d0> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb110> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb150> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb190> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb1d0> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb210> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb250> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb290> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb2d0> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb310> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb350> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb390> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb3d0> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb410> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb450> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb490> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb4d0> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb510> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb550> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb590> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb5d0> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb610> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb650> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb690> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb6d0> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb710> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb750> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb790> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb7d0> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb810> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb850> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb890> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb8d0> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb910> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb950> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb990> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eb9d0> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eba10> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eba50> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80eba90> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebad0> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebb10> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebb50> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebb90> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebbd0> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebc10> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebc50> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebc90> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebcd0> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebd10> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebd50> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebd90> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebdd0> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebe10> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebe50> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebe90> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebed0> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebf10> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebf50> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebf90> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ebfd0> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4050> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4090> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f40d0> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4110> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4150> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4190> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f41d0> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4210> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4250> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4290> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f42d0> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4310> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4350> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4390> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f43d0> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4410> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4450> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4490> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f44d0> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4510> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4550> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4590> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f45d0> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4610> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4650> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4690> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f46d0> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4710> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4750> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4790> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f47d0> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4810> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4850> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4890> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f48d0> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4910> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4950> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4990> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f49d0> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4a10> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4a50> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4a90> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4ad0> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4b10> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4b50> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4b90> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4bd0> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4c10> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4c50> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4c90> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4cd0> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4d10> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4d50> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4d90> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4dd0> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4e10> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4e50> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4e90> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4ed0> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4f10> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4f50> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4f90> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f4fd0> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9050> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9090> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f90d0> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9110> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9150> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9190> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f91d0> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9210> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9250> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9290> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f92d0> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9310> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9350> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9390> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f93d0> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9410> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9450> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9490> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f94d0> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9510> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9550> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9590> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f95d0> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9610> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9650> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9690> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f96d0> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9710> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9750> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9790> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f97d0> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9810> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9850> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9890> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f98d0> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9910> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9950> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9990> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f99d0> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9a10> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9a50> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9a90> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9ad0> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9b10> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9b50> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9b90> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9bd0> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9c10> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9c50> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9c90> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9cd0> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9d10> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9d50> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9d90> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9dd0> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9e10> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9e50> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9e90> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9ed0> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9f10> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9f50> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9f90> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80f9fd0> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff050> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff090> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff0d0> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff110> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff150> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff190> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff1d0> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff210> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x80ff250> (224 of 224)
# /vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/mayavi/preferences/preference_manager.py:24: UserWarning: Module PIL was already imported from /usr/lib/python2.7/dist-packages/PIL/__init__.pyc, but /vol/atlas/homes/ja310/.virtualenvs/pybug/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Use **pickle** to load a previously build *AAM*

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa', "rb"))

reference_frame = aam["template"]
appearance_model = aam["appearance_model"]
shape_model = aam["shape_model_1"]

# %% [markdown]
# ### 2. Fit
#
# We start randomly selecting an image to fit.

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[ind].as_greyscale()
test_shape = shapes[ind]

# %% [markdown]
# Visualize the ground truth landmarks and warped appearance for the selected test image.

# %%
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.warp import scipy_warp

source = reference_frame.landmarks['PTS'].all_landmarks
trilist = reference_frame.get_landmark_set('ibug_68_trimesh').landmark_dict['tri'].trilist
template_pwa = PiecewiseAffineTransform(source.points, test_shape.points, trilist)
template = scipy_warp(test_image, reference_frame, template_pwa)

test_image.add_landmark_set("ground_truth", {"ground_truth": test_shape})
test_image.get_landmark_set("ground_truth").with_label('ground_truth').view()

template.add_landmark_set('reference', {'reference': source})
template.get_landmark_set('reference').with_label('reference').view()

# %% [markdown]
# Then we build a dummy Similarity Transform and a dummy Statistically Driven Transform

# %%
from pybug.transform.statisticallydriven import StatisticallyDrivenTransform
from pybug.transform.affine import SimilarityTransform
from scipy.spatial import Delaunay

def pwa_constructor(src_landmarks, tgt_landmarks):
    tri = Delaunay(src_landmarks)
    return PiecewiseAffineTransform(src_landmarks, tgt_landmarks, tri.simplices)

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

dummy_statistically_driven_transform = StatisticallyDrivenTransform(shape_model, pwa_constructor,
                                                                    source=source, global_transform=global_transform,
                                                                    composition='both')

# %% [markdown]
# Build the "fitter" object.

# %%
from pybug.align.lucaskanade.residual import LSIntensity, GradientImages
from pybug.align.lucaskanade.base import SimultaneousAppearanceForwardAdditive, SimultaneousAppearanceForwardCompositional, SimultaneousAppearanceInverseCompositional

residual = LSIntensity()
sfa = SimultaneousAppearanceForwardAdditive(appearance_model, residual, dummy_statistically_driven_transform)
sfc = SimultaneousAppearanceForwardCompositional(appearance_model, residual, dummy_statistically_driven_transform)
sic = SimultaneousAppearanceInverseCompositional(appearance_model, residual, dummy_statistically_driven_transform)

# %% [markdown]
# Initialize by scaling and translating the shape model mean using the scale and translation parameters from the ground truth shape.

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# estimate similarity transform
similarity_transform = SimilarityTransform.estimate(shape_model.mean.points, test_shape.points)
global_parameters = similarity_transform.as_vector()
# kill rotation
global_parameters[1] = 0
# add random gaussian noise to the ground truth parameters
#global_parameters += 0.1 * np.random.randn(4) 

global_transform = SimilarityTransform.from_vector(global_parameters)

aligned_test_points = global_transform.inverse.apply(test_shape.points)
aligned_test_shape = PointCloud(aligned_test_points)
weights = shape_model.project(aligned_test_shape)

initial_parameters = np.concatenate([global_parameters, np.zeros_like(weights)])

# %% [markdown]
# Check the correctness of the initialization.

# %%
initial_transform = dummy_statistically_driven_transform.from_vector(initial_parameters)
initial_warped_image = scipy_warp(test_image, template, initial_transform)

test_image.add_landmark_set("initial", {"initial": initial_transform.target})
test_image.get_landmark_set("initial").view()

initial_warped_image.add_landmark_set('reference', {'reference': source})
initial_warped_image.get_landmark_set('reference').with_label('reference').view()

# %% [markdown]
# Fit using the 3 curent methods for image alignment.

# %%
#optimal_transform_1 = sfa.align(test_image, initial_parameters, max_iters=60)
#optimal_transform_2 = sfc.align(test_image, initial_parameters, max_iters=60)
optimal_transform_3 = sic.align(test_image, initial_parameters, max_iters=160)

# %% [markdown]
# Visualize the results.

# %%
fitted_appearance_1 = scipy_warp(test_image, template, optimal_transform_1)
fitted_appearance_2 = scipy_warp(test_image, template, optimal_transform_2)
fitted_appearance_3 = scipy_warp(test_image, template, optimal_transform_3)

test_image.add_landmark_set('fitting_results', {'sfa': optimal_transform_1.target,
                                                'sfc': optimal_transform_2.target,
                                                'sic': optimal_transform_3.target})
test_image.get_landmark_set('fitting_results').with_label('sfa').view()
test_image.get_landmark_set('fitting_results').with_label('sfc').view()
test_image.get_landmark_set('fitting_results').with_label('sic').view()

fitted_appearance_1.add_landmark_set('reference', {'reference': source})
fitted_appearance_1.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))
fitted_appearance_2.add_landmark_set('reference', {'reference': source})
fitted_appearance_2.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))
fitted_appearance_3.add_landmark_set('reference', {'reference': source})
fitted_appearance_3.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc'
