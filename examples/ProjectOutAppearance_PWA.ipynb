# %% [markdown]
# # Fit an AAM to an Input Images
# ##### Version 0.1
#
# ### 1. Load the Data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset.

# %%
from pybug.io import auto_import
from pybug.landmark.labels import  labeller, ibug_68_points, ibug_68_contour, ibug_68_trimesh

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/vol/atlas/databases/lfpw/test/' + '*.png')

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points)
labeller(images, 'PTS', ibug_68_contour)
labeller(images, 'PTS', ibug_68_trimesh)

from pybug.shape import PointCloud

points = [img.landmarks['PTS'].all_landmarks.points - 1  for img in images]
shapes = [PointCloud(p) for p in points]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x77eed10> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f89d0> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8a10> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8a50> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8a90> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8ad0> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8b10> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8b50> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8b90> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8bd0> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8c10> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8c50> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8c90> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8cd0> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8d10> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8d50> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8d90> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8dd0> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8e10> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8e50> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8e90> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8ed0> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8f10> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8f50> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8f90> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x77f8fd0> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806050> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806090> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78060d0> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806110> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806150> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806190> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78061d0> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806210> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806250> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806290> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78062d0> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806310> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806350> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806390> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78063d0> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806410> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806450> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806490> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78064d0> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806510> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806550> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806590> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78065d0> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806610> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806650> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806690> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78066d0> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806710> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806750> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806790> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78067d0> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806810> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806850> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806890> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78068d0> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806910> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806950> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806990> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78069d0> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806a10> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806a50> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806a90> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806ad0> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806b10> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806b50> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806b90> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806bd0> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806c10> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806c50> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806c90> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806cd0> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806d10> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806d50> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806d90> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806dd0> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806e10> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806e50> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806e90> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806ed0> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806f10> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806f50> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806f90> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7806fd0> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f050> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f090> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f0d0> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f110> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f150> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f190> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f1d0> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f210> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f250> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f290> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f2d0> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f310> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f350> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f390> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f3d0> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f410> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f450> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f490> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f4d0> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f510> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f550> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f590> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f5d0> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f610> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f650> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f690> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f6d0> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f710> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f750> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f790> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f7d0> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f810> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f850> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f890> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f8d0> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f910> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f950> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f990> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780f9d0> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fa10> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fa50> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fa90> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fad0> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fb10> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fb50> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fb90> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fbd0> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fc10> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fc50> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fc90> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fcd0> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fd10> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fd50> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fd90> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fdd0> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fe10> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fe50> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fe90> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780fed0> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780ff10> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780ff50> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780ff90> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x780ffd0> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814050> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814090> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78140d0> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814110> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814150> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814190> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78141d0> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814210> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814250> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814290> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78142d0> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814310> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814350> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814390> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78143d0> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814410> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814450> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814490> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78144d0> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814510> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814550> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814590> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78145d0> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814610> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814650> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814690> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78146d0> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814710> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814750> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814790> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78147d0> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814810> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814850> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814890> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78148d0> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814910> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814950> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814990> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x78149d0> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814a10> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814a50> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814a90> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814ad0> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814b10> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814b50> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814b90> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814bd0> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814c10> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814c50> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814c90> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814cd0> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814d10> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814d50> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814d90> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814dd0> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814e10> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814e50> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814e90> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814ed0> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814f10> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814f50> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814f90> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x7814fd0> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a050> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a090> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a0d0> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a110> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a150> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a190> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a1d0> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a210> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x781a250> (224 of 224)
# /vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/mayavi/preferences/preference_manager.py:24: UserWarning: Module PIL was already imported from /usr/lib/python2.7/dist-packages/PIL/__init__.pyc, but /vol/atlas/homes/ja310/.virtualenvs/pybug/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Use **pickle** to load a previously build *AAM*

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa', "rb"))

reference_frame = aam["template"]
appearance_model = aam["appearance_model"]
shape_model = aam["shape_model_1"]

# %% [markdown]
# ### 2. Fit
#
# We start randomly selecting an image to fit.

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[ind].as_greyscale()
test_shape = shapes[ind]

# %% [markdown]
# Visualize the ground truth landmarks and warped appearance for the selected test image.

# %%
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.warp import scipy_warp

source = reference_frame.landmarks['PTS'].all_landmarks
trilist = reference_frame.get_landmark_set('ibug_68_trimesh').landmark_dict['tri'].trilist
template_pwa = PiecewiseAffineTransform(source.points, test_shape.points, trilist)
template = scipy_warp(test_image, reference_frame, template_pwa)

test_image.add_landmark_set("ground_truth", {"ground_truth": test_shape})
test_image.get_landmark_set("ground_truth").with_label('ground_truth').view()

template.add_landmark_set('reference', {'reference': source})
template.get_landmark_set('reference').with_label('reference').view()

# %% [markdown]
# Then we build a dummy Similarity Transform and a dummy Statistically Driven Transform

# %%
from pybug.transform.statisticallydriven import StatisticallyDrivenTransform
from pybug.transform.affine import SimilarityTransform
from scipy.spatial import Delaunay

def pwa_constructor(src_landmarks, tgt_landmarks):
    tri = Delaunay(src_landmarks)
    return PiecewiseAffineTransform(src_landmarks, tgt_landmarks, tri.simplices)

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

dummy_statistically_driven_transform = StatisticallyDrivenTransform(shape_model, pwa_constructor,
                                                                    source=source, global_transform=global_transform,
                                                                    composition='both')

# %% [markdown]
# Build the "fitter" object.

# %%
from pybug.align.lucaskanade.residual import LSIntensity, GradientImages
from pybug.align.lucaskanade.base import ProjectOutAppearanceForwardAdditive, ProjectOutAppearanceForwardCompositional, ProjectOutAppearanceInverseCompositional

residual = LSIntensity()
pofa = ProjectOutAppearanceForwardAdditive(appearance_model, residual, dummy_statistically_driven_transform)
pofc = ProjectOutAppearanceForwardCompositional(appearance_model, residual, dummy_statistically_driven_transform)
poic = ProjectOutAppearanceInverseCompositional(appearance_model, residual, dummy_statistically_driven_transform)

# %% [markdown]
# Initialize by scaling and translating the shape model mean using the scale and translation parameters from the ground truth shape.

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# estimate similarity transform
similarity_transform = SimilarityTransform.estimate(shape_model.mean.points, test_shape.points)
global_parameters = similarity_transform.as_vector()
# kill rotation
global_parameters[1] = 0
# add random gaussian noise to the ground truth parameters
global_parameters += 0.1 * np.random.randn(4) 

global_transform = SimilarityTransform.from_vector(global_parameters)

aligned_test_points = global_transform.inverse.apply(test_shape.points)
aligned_test_shape = PointCloud(aligned_test_points)
weights = shape_model.project(aligned_test_shape)

initial_parameters = np.concatenate([global_parameters, np.zeros_like(weights)])

# %% [markdown]
# Check the correctness of the initialization.

# %%
initial_transform = dummy_statistically_driven_transform.from_vector(initial_parameters)
initial_warped_image = scipy_warp(test_image, template, initial_transform)

test_image.add_landmark_set("initial", {"initial": initial_transform.target})
test_image.get_landmark_set("initial").view()

initial_warped_image.add_landmark_set('reference', {'reference': source})
initial_warped_image.get_landmark_set('reference').with_label('reference').view()

# %% [markdown]
# Fit using the 3 curent methods for image alignment.

# %%
optimal_transform_1 = pofa.align(test_image, initial_parameters, max_iters=60)
optimal_transform_2 = pofc.align(test_image, initial_parameters, max_iters=60)
optimal_transform_3 = poic.align(test_image, initial_parameters, max_iters=60)

# %% [markdown]
# Visualize the results.

# %%
fitted_appearance_1 = scipy_warp(test_image, template, optimal_transform_1)
fitted_appearance_2 = scipy_warp(test_image, template, optimal_transform_2)
fitted_appearance_3 = scipy_warp(test_image, template, optimal_transform_3)

test_image.add_landmark_set('fitting_results', {'pofa': optimal_transform_1.target,
                                                'pofc': optimal_transform_2.target,
                                                'poic': optimal_transform_3.target})
test_image.get_landmark_set('fitting_results').with_label('pofa').view()
test_image.get_landmark_set('fitting_results').with_label('pofc').view()
test_image.get_landmark_set('fitting_results').with_label('poic').view()

fitted_appearance_1.add_landmark_set('reference', {'reference': source})
fitted_appearance_1.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))
fitted_appearance_2.add_landmark_set('reference', {'reference': source})
fitted_appearance_2.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))
fitted_appearance_3.add_landmark_set('reference', {'reference': source})
fitted_appearance_3.get_landmark_set('reference').with_label('reference').view()
gcf().set_size_inches((6,6))

# %%
import matplotlib
matplotlib.matplotlib_fname()
