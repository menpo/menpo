# %% [markdown]
# # Fit an AAM to an Input Images
# ##### Version 0.1
#
# ### 1. Load the Data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset.

# %%
from pybug.io import auto_import
from pybug.landmark.labels import  labeller, ibug_68_points, ibug_68_contour, ibug_68_trimesh

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/vol/atlas/databases/lfpw/test/' + '*.png')

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points)
labeller(images, 'PTS', ibug_68_contour)
labeller(images, 'PTS', ibug_68_trimesh)

from pybug.shape import PointCloud

points = [img.landmarks['PTS'].all_landmarks.points - 1  for img in images]
shapes = [PointCloud(p) for p in points]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x89b9d10> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c39d0> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3a10> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3a50> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3a90> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3ad0> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3b10> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3b50> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3b90> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3bd0> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3c10> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3c50> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3c90> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3cd0> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3d10> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3d50> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3d90> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3dd0> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3e10> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3e50> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3e90> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3ed0> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3f10> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3f50> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3f90> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89c3fd0> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1050> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1090> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d10d0> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1110> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1150> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1190> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d11d0> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1210> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1250> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1290> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d12d0> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1310> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1350> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1390> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d13d0> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1410> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1450> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1490> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d14d0> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1510> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1550> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1590> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d15d0> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1610> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1650> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1690> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d16d0> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1710> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1750> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1790> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d17d0> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1810> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1850> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1890> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d18d0> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1910> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1950> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1990> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d19d0> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1a10> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1a50> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1a90> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1ad0> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1b10> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1b50> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1b90> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1bd0> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1c10> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1c50> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1c90> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1cd0> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1d10> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1d50> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1d90> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1dd0> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1e10> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1e50> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1e90> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1ed0> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1f10> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1f50> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1f90> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89d1fd0> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da050> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da090> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da0d0> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da110> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da150> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da190> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da1d0> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da210> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da250> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da290> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da2d0> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da310> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da350> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da390> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da3d0> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da410> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da450> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da490> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da4d0> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da510> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da550> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da590> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da5d0> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da610> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da650> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da690> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da6d0> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da710> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da750> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da790> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da7d0> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da810> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da850> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da890> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da8d0> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da910> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da950> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da990> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89da9d0> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daa10> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daa50> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daa90> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daad0> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dab10> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dab50> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dab90> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dabd0> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dac10> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dac50> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dac90> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dacd0> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dad10> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dad50> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dad90> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dadd0> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dae10> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dae50> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dae90> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daed0> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daf10> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daf50> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89daf90> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dafd0> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df050> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df090> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df0d0> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df110> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df150> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df190> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df1d0> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df210> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df250> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df290> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df2d0> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df310> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df350> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df390> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df3d0> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df410> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df450> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df490> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df4d0> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df510> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df550> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df590> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df5d0> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df610> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df650> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df690> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df6d0> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df710> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df750> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df790> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df7d0> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df810> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df850> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df890> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df8d0> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df910> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df950> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df990> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89df9d0> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfa10> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfa50> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfa90> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfad0> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfb10> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfb50> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfb90> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfbd0> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfc10> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfc50> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfc90> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfcd0> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfd10> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfd50> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfd90> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfdd0> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfe10> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfe50> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfe90> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dfed0> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dff10> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dff50> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dff90> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89dffd0> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5050> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5090> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e50d0> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5110> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5150> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5190> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e51d0> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5210> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x89e5250> (224 of 224)
# /vol/atlas/homes/ja310/.virtualenvs/pybug/local/lib/python2.7/site-packages/mayavi/preferences/preference_manager.py:24: UserWarning: Module PIL was already imported from /usr/lib/python2.7/dist-packages/PIL/__init__.pyc, but /vol/atlas/homes/ja310/.virtualenvs/pybug/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Use **pickle** to load a previously build *AAM*

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa', "rb"))

reference_frame = aam["template"]
appearance_model = aam["appearance_model"]
shape_model = aam["shape_model_1"]

# %% [markdown]
# ### 2. Fit
#
# We start randomly selecting an image to fit.

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[195].as_greyscale()
test_shape = shapes[195]

# %% [markdown]
# Then we build a dummy Similarity Transform and a dummy Statistically Driven Transform

# %%
from pybug.transform.statisticallydriven import StatisticallyDrivenTransform
from pybug.align.nonrigid import TPS
from pybug.transform.affine import SimilarityTransform
from scipy.spatial import Delaunay

def tps_constructor(src_landmarks, tgt_landmarks):
    tps = TPS(src_landmarks, tgt_landmarks)
    return tps.transform

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

source = reference_frame.landmarks['PTS'].all_landmarks
dummy_statistically_driven_transform = StatisticallyDrivenTransform(shape_model, tps_constructor,
                                                                    source=source, global_transform=global_transform,
                                                                    composition='model')

# %% [markdown]
# Because we will not be using the Appearance Model yet, we need to build the appropiate template.

# %%
from pybug.warp import scipy_warp

trilist = reference_frame.get_landmark_set('ibug_68_trimesh').landmark_dict['tri'].trilist

template_tps = TPS(source.points, test_shape.points)
template = scipy_warp(test_image, reference_frame, template_tps.transform)

template.view()

# %% [markdown]
# Build the "fitter" objects.

# %%
from pybug.align.lucaskanade.residual import LSIntensity
from pybug.align.lucaskanade.base import ImageForwardAdditive, ImageForwardCompositional, ImageInverseCompositional

residual = LSIntensity()
ifa = ImageForwardAdditive(template, residual, dummy_statistically_driven_transform)
ifc = ImageForwardCompositional(template, residual, dummy_statistically_driven_transform)
iic = ImageInverseCompositional(template, residual, dummy_statistically_driven_transform)

# %% [markdown]
# Initialize by scaling and translating the shape model mean using the scale and translation parameters from the ground truth shape.

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# estimate similarity transform
similarity_transform = SimilarityTransform.estimate(shape_model.mean.points, test_shape.points)
global_parameters = similarity_transform.as_vector()
# kill rotation
global_parameters[1] = 0
# add random gaussian noise to the ground truth parameters
global_parameters += 0.1 * np.random.randn(4) 

global_transform = SimilarityTransform.from_vector(global_parameters)

aligned_test_points = global_transform.inverse.apply(test_shape.points)
aligned_test_shape = PointCloud(aligned_test_points)
weights = shape_model.project(aligned_test_shape)

initial_parameters = np.concatenate([global_parameters, np.zeros_like(weights)])

# %% [markdown]
# Check the correctness of the initialization.

# %%
initial_transform = dummy_statistically_driven_transform.from_vector(initial_parameters)
initial_warped_image = scipy_warp(test_image, template, initial_transform.transform)

test_image.add_landmark_set("initial", {"initial": initial_transform.target})
test_image.get_landmark_set("initial").view()
initial_warped_image.view()

# %% [markdown]
# Fit using the 3 curent methods for image alignment.

# %%
optimal_transform_1 = ifa.align(test_image, initial_parameters, max_iters=50)
optimal_transform_2 = ifc.align(test_image, initial_parameters, max_iters=150)
optimal_transform_3 = iic.align(test_image, initial_parameters, max_iters=150)

# %% [markdown]
# Visualize the results.

# %%
fitted_appearance_1 = scipy_warp(test_image, template, optimal_transform_1)
fitted_appearance_2 = scipy_warp(test_image, template, optimal_transform_2)
fitted_appearance_3 = scipy_warp(test_image, template, optimal_transform_3)

fitted_appearance_1.view()
fitted_appearance_2.view()
fitted_appearance_3.view()

test_image.add_landmark_set("fitting_results", {"ifa": optimal_transform_1.target,
                                                "ifc": optimal_transform_2.target,
                                                "iic": optimal_transform_3.target})
test_image.get_landmark_set("fitting_results").with_label("ifa").view()
test_image.get_landmark_set("fitting_results").with_label("ifc").view()
test_image.get_landmark_set("fitting_results").with_label("iic").view()
